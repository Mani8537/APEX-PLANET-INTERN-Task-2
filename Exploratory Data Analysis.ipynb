# %% [markdown]
# ## Exploratory Data Analysis(EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
Data = pd.read_csv("/content/Sales_Dataset.csv")
df = pd.DataFrame(Data)
df.head(4)
# Out:
#    Order_ID  Customer_ID  Customer_Age  Gender     City Product_Category  \
# 0     10001         3061            21    Male    Delhi  Home Appliances
# 1     10002         2235            21  Female  Chennai           Beauty
# 2     10003         3096            21    Male    Delhi            Books
# 3     10004         2905            51    Male    Delhi  Home Appliances
#
#   Product_Name  Quantity  Unit_Price  Total_Amount Payment_Method  Rating  \
# 0   Smartphone         2     3100.57       6201.14           Cash       3
# 1   Smartphone         1      983.85        983.85     Debit Card       1
# 2     Cookware         2     1385.43       2770.86            UPI       4
# 3        Novel         3     1645.97       4937.91           Cash       5
#
#                       Order_Date
# 0  2024-01-01 00:00:00.000000000
# 1  2024-01-01 16:52:43.005780346
# 2  2024-01-02 09:45:26.011560693
# 3  2024-01-03 02:38:09.017341040

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          520 non-null    int64
#  1   Customer_ID       520 non-null    int64
#  2   Customer_Age      520 non-null    int64
#  3   Gender            520 non-null    object
#  4   City              520 non-null    object
#  5   Product_Category  520 non-null    object
#  6   Product_Name      520 non-null    object
#  7   Quantity          520 non-null    int64
#  8   Unit_Price        520 non-null    float64
#  9   Total_Amount      520 non-null    float64
#  10  Payment_Method    520 non-null    object
#  11  Rating            520 non-null    int64
#  12  Order_Date        520 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 52.9+ KB

# %%
df.isnull().sum()
# Out:
# Order_ID            0
# Customer_ID         0
# Customer_Age        0
# Gender              0
# City                0
# Product_Category    0
# Product_Name        0
# Quantity            0
# Unit_Price          0
# Total_Amount        0
# Payment_Method      0
# Rating              0
# Order_Date          0
# dtype: int64

# %%
df["Order_Date"] = pd.to_datetime(df["Order_Date"])

# %%
df
# Out:
#      Order_ID  Customer_ID  Customer_Age  Gender       City Product_Category  \
# 0       10001         3061            21    Male      Delhi  Home Appliances
# 1       10002         2235            21  Female    Chennai           Beauty
# 2       10003         3096            21    Male      Delhi            Books
# 3       10004         2905            51    Male      Delhi  Home Appliances
# 4       10005         4763            53    Male    Kolkata         Clothing
# ..        ...          ...           ...     ...        ...              ...
# 515     10516         4587            49  Female      Delhi            Books
# 516     10517         2691            54    Male    Kolkata         Clothing
# 517     10518         2939            30    Male  Hyderabad           Sports
# 518     10519         2174            56  Female      Delhi         Clothing
# 519     10520         3033            37  Female    Kolkata           Sports
#
#      Product_Name  Quantity  Unit_Price  Total_Amount Payment_Method  Rating  \
# 0      Smartphone         2     3100.57       6201.14           Cash       3
# 1      Smartphone         1      983.85        983.85     Debit Card       1
# 2        Cookware         2     1385.43       2770.86            UPI       4
# 3           Novel         3     1645.97       4937.91           Cash       5
# 4     Cricket Bat         5     4204.53      21022.65     Debit Card       3
# ..            ...       ...         ...           ...            ...     ...
# 515    Headphones         1     2915.98       2915.98    Credit Card       1
# 516       T-Shirt         4     3336.63      13346.52            UPI       2
# 517        Laptop         4     1578.84       6315.36    Net Banking       4
# 518        Laptop         2     4774.83       9549.66            UPI       2
# 519  Skincare Kit         4     3447.94      13791.76            UPI       2
#
#                        Order_Date
# 0   2024-01-01 00:00:00.000000000
# 1   2024-01-01 16:52:43.005780346
# 2   2024-01-02 09:45:26.011560693
# 3   2024-01-03 02:38:09.017341040
# 4   2024-01-03 19:30:52.023121387
# ..                            ...
# 515 2024-12-28 04:29:07.976878612
# 516 2024-12-28 21:21:50.982658960
# 517 2024-12-29 14:14:33.988439308
# 518 2024-12-30 07:07:16.994219652
# 519 2024-12-31 00:00:00.000000000
#
# [520 rows x 13 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#            Order_ID  Customer_ID  Customer_Age    Quantity   Unit_Price  \
# count    520.000000   520.000000    520.000000  520.000000   520.000000
# mean   10260.500000  3506.540385     38.721154    2.965385  2584.704519
# min    10001.000000  2015.000000     18.000000    1.000000   305.240000
# 25%    10130.750000  2727.750000     28.000000    2.000000  1382.140000
# 50%    10260.500000  3486.000000     39.000000    3.000000  2594.280000
# 75%    10390.250000  4257.250000     49.000000    4.000000  3760.867500
# max    10520.000000  4994.000000     59.000000    5.000000  4999.420000
# std      150.255338   865.058185     12.157965    1.372295  1360.806353
#
#        Total_Amount      Rating           Order_Date
# count    520.000000  520.000000                  520
# mean    7546.484115    3.063462  2024-07-01 12:00:00
# min      353.930000    1.000000  2024-01-01 00:00:00
# 25%     3186.985000    2.000000  2024-04-01 06:00:00
# 50%     5845.815000    3.000000  2024-07-01 12:00:00
# 75%    10857.415000    4.000000  2024-09-30 18:00:00
# max    24997.100000    5.000000  2024-12-31 00:00:00
# std     5531.922582    1.424331                  NaN

# %%
df.describe(include="object")
# Out:
#        Gender     City Product_Category Product_Name Payment_Method
# count     520      520              520          520            520
# unique      2        7                6           10              5
# top      Male  Kolkata            Books        Novel     Debit Card
# freq      266       87               97           69            111

# %%
# Value count for categorical data
df["Gender"].value_counts()
# Out:
# Gender
# Male      266
# Female    254
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="Gender", data=df)
plt.title("Gender Distribution")
plt.show()

# %%
# Product Category Distribution
df["Product_Category"].value_counts()
# Out:
# Product_Category
# Books              97
# Clothing           94
# Electronics        88
# Beauty             85
# Home Appliances    78
# Sports             78
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="Product_Category", data=df)
plt.xticks(rotation=45)
plt.title("Product Category Distribution")
plt.show()

# %%
# Payment Method
df["Payment_Method"].value_counts()
# Out:
# Payment_Method
# Debit Card     111
# Cash           104
# Net Banking    103
# UPI            102
# Credit Card    100
# Name: count, dtype: int64

# %%
sns.countplot(x="Payment_Method", data=df)
plt.title("Payment Method Distribution")
plt.show()

# %% [markdown]
# #Univariate Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df['Customer_Age'])
plt.title('Customer Age Distribution')
plt.show()

# %%
sns.countplot(x='Product_Category', data=df)
plt.xticks(rotation=45)
plt.title('Product Category Distribution')
plt.show()

# %% [markdown]
# #Multivariate Analysis

# %%
sns.scatterplot(x='Customer_Age', y='Total_Amount', data=df)
plt.title('Age vs Spending')
plt.show()

# %% [markdown]
# #Correlation Matrix

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True)
plt.title('Correlation Matrix')
plt.show()
